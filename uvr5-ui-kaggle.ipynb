# %% [markdown]
# # **🎵 UVR5 UI 🎵**

# %% [markdown]
# ### Kaggle notebook created by **[ArisDev](https://github.com/aris-py)**
#
# <br> **If you liked this Kaggle notebook you can star my fork on [GitHub](https://github.com/aris-py/UVR5-UI-Kaggle-Modified).** <br>
#
# <a href="https://colab.research.google.com/github/Eddycrack864/UVR5-UI/blob/main/UVR_UI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# UVR5 UI oficcial repo by Eddy: [Click Here](https://github.com/Eddycrack864/UVR5-UI)
#
# ![](https://count.nett.moe/get/uvr5_ui_colab/img?theme=rule34)

# %% [markdown]
# # Installation
# ##### This takes around 2 minutes

# %%
from IPython.display import clear_output
import codecs
# !python -m venv uvrdependencies
# %cd /kaggle/working
gitrepo = codecs.decode('uggcf://tvguho.pbz/Rqqlpenpx864/HIE5-HV.tvg','rot_13')
repopath = codecs.decode('HIE5-HV/erdhverzragf.gkg','rot_13')
# !git clone https://github.com/aris-py/UVR5-UI-Kaggle-Modified.git > /dev/null 2>&1
# %cd /kaggle/working/UVR5-UI-Kaggle-Modified/
# !pip install git+https://github.com/Vidalnt/imjoy-elfinder.git > /dev/null 2>&1
clear_output()
print("Installing dependencies...")
# !pip install -r requirements.txt > /dev/null 2>&1
# !python -m pip install ort-nightly-gpu --index-url=https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/ort-cuda-12-nightly/pypi/simple/ > /dev/null 2>&1
# !source uvrdependencies/bin/activate
clear_output()
print('Installation done!')

# %% [markdown]
# # Run UI

# %%
# Run UVR5 WebUI
from IPython.display import clear_output
import codecs
import os
import sys
# %cd /kaggle/working/UVR5-UI-Kaggle-Modified
# !python -m venv myenv
app = codecs.decode('HIE5-HV/ncc.cl','rot_13')
os.system(f"imjoy-elfinder --root-dir=/kaggle/working --port 9876  > /dev/null 2>&1 &")
clear_output()
Url="Ngrok" 
#@markdown - Token is only needed if you are using Ngrok. You can make an account on ngrok https://dashboard.ngrok.com/signup for free.
#@markdown - https://dashboard.ngrok.com/get-started/your-authtoken to get your auth token, and place it here:
Token="Your_Token_Here" # <---- replace Your_Token_Here with your ngrok token
if Url=="Gradio":
  # !python $runpice --share

  # !python $app --listen-port 9876
  # !python $app --listen-port 9999
else:
  # !pip install pyngrok
clear_output()
from pyngrok import ngrok
ngrok.set_auth_token(Token)
ngrok.kill()
uvr_tunel = ngrok.connect(9999)
file_tunnel = ngrok.connect(9876)
print("UVR5 URL:", uvr_tunel.public_url)
print("File URL:", file_tunnel.public_url)
# !source myenv/bin/activate
# !python app.py
